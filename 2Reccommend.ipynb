# %%
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt


import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. Connect to Spotify API
#
# Useful links:
# 1. https://developer.spotify.com/dashboard/
# 2. https://spotipy.readthedocs.io/en/2.16.1/

# %%
# spotify_df = pd.read_feather('spotify_df.feather')
# complete_feature_set = pd.read_feather('complete_feature_set.feather')

# %%
spotify_df = pd.read_feather('spotify_df_low.feather')
complete_feature_set = pd.read_feather('cfs_final.feather')

# %%
spotify_df[spotify_df['id']=='7qiZfU4dY1lWllzX7mPBI3']['url'].values[0]
# Out:
# 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96'

# %%
default_date = pd.to_datetime('2021-04-27 08:09:52+00:00')
defailt_url = 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a'

# %%
id_list = ["7qiZfU4dY1lWllzX7mPBI3", "1i1fxkWeaMmKEB4T7zqbzK", "0e7ipj03S05BNilyu5bRzt", "0VjIjW4GlUZAMYd2vXMi3b", "2Fxmhks0bxGSBdJ92vM42m", "0TK2YIli7K1leLovkQiNik", "3KkXRkHbMCARz0aVfEt68P", "1rfofaqEpACxVEHIZBJe6W", "0pqnGHJpmpxLKifKRmU6WP", "3OnOomd79OjqSYHchCQ6ht", "1RagpNpkD3KcjXMLGMe99V", "7IBSffWIu7P2MC7kMwy2FM", "4O1uCappFiU3bisYUdUBWy", "1Faq8G2y56A8fRv7HsLq25", "7yExgsBx35vegvvLd2415v", "0HCnj7pfrvshnocOJUFeit", "6nO3tr47nr2P7f3hXb8JIo", "6TrjaOqUwdKQ7KNxJr2s9Y", "0Z1nbG2KOuRKntstSAkSox", "6v3KW9xbzN5yKLt9YKDYA2", "3i9UVldZOE0aD0JnyfAZZ0", "2bT1PH7Cw3J9p3t7nlXCdh", "7gY3cyGcB2wnk2xDXiA0pe", "59tskctgqUmjCWAwhzYAFm", "6zegtH6XXd2PDPLvy1Y0n2", "0ClPIeT6MSgfSgQ9ZrJbAq", "5FNS5Vj69AhRGJWjhrAd01", "4cZ3UsiKd1kUQIaq4BFIj2", "3je88Q4OvTqIx7BFRFYvRA", "0tgVpDi06FyKpA1z0VMD4v", "3VlbOrM6nYPprVvzBZllE5", "7krbSH3rd8lhIZvuzTV3Bl", "1bhUWB0zJMIKr9yVPrkEuI", "78zUxUPvONPgMIt46q5be6", "2gMXnyrvIjhVBUZwvLZDMP", "51ChrwmUPDJvedPQnIU8Ls", "7FyhrRNRJOZSM8IeuAx7su", "7krbSH3rd8lhIZvuzTV3Bl", "1bhUWB0zJMIKr9yVPrkEuI", "78zUxUPvONPgMIt46q5be6", "12OLyHDxt6dqlAybSPFBK3"]

# %%
def createPlaylist(id_list):
    idDF = pd.DataFrame({'artist':[],'name':[],'id':[],'url':[],'date_added':[]})
    for id in id_list:
        artistName = spotify_df[spotify_df['id'] == id]['artists_upd_v1'].iloc[0][0]
        songName = spotify_df[spotify_df['id'] == id]['name'].values[0]
        newRow = {'artist':artistName,'name':songName,'id':id,'url':defailt_url,'date_added':default_date}
        idDF = idDF.append(newRow,ignore_index=True)
    return idDF

# %%
createPlaylist(id_list)
# Out:
#                         artist  \
# 0                   Ed Sheeran
# 1             The Chainsmokers
# 2                  Post Malone
# 3                   The Weeknd
# 4                Billie Eilish
# 5                 Shawn Mendes
# 6                  Post Malone
# 7               Camila Cabello
# 8              Imagine Dragons
# 9                        Migos
# 10                 Wiz Khalifa
# 11                 Wiz Khalifa
# 12  YoungBoy Never Broke Again
# 13                         NAV
# 14                 Yella Beezy
# 15                       Gunna
# 16                         NAV
# 17                  Tory Lanez
# 18                  Tory Lanez
# 19                Shawn Mendes
# 20                Taylor Swift
# 21                Shawn Mendes
# 22               Avril Lavigne
# 23           Sabrina Carpenter
# 24               Ariana Grande
# 25                Charlie Puth
# 26                 AJ Mitchell
# 27                 Jack & Jack
# 28                  PRETTYMUCH
# 29                  Ed Sheeran
# 30                   Sam Smith
# 31                James Arthur
# 32                  Ed Sheeran
# 33                    James TW
# 34               Lewis Capaldi
# 35                  Ed Sheeran
# 36                   Sam Smith
# 37                James Arthur
# 38                  Ed Sheeran
# 39                    James TW
# 40               Lewis Capaldi
#
#                                                  name                      id  \
# 0                                        Shape of You  7qiZfU4dY1lWllzX7mPBI3
# 1                                   Don't Let Me Down  1i1fxkWeaMmKEB4T7zqbzK
# 2                                           rockstar   0e7ipj03S05BNilyu5bRzt
# 3                                     Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 4                                             bad guy  2Fxmhks0bxGSBdJ92vM42m
# 5                                            Señorita  0TK2YIli7K1leLovkQiNik
# 6       Sunflower - Spider-Man: Into the Spider-Verse  3KkXRkHbMCARz0aVfEt68P
# 7                                             Havana   1rfofaqEpACxVEHIZBJe6W
# 8                                            Believer  0pqnGHJpmpxLKifKRmU6WP
# 9                                           Notice Me  3OnOomd79OjqSYHchCQ6ht
# 10                                             Fr Fr   1RagpNpkD3KcjXMLGMe99V
# 11                                 Hopeless Romantic   7IBSffWIu7P2MC7kMwy2FM
# 12                            I Am Who They Say I Am   4O1uCappFiU3bisYUdUBWy
# 13                                        Wanted You   1Faq8G2y56A8fRv7HsLq25
# 14                                      That's On Me   7yExgsBx35vegvvLd2415v
# 15                                            Top Off  0HCnj7pfrvshnocOJUFeit
# 16                                          Champion   6nO3tr47nr2P7f3hXb8JIo
# 17                                           Shooters  6TrjaOqUwdKQ7KNxJr2s9Y
# 18                                      FeRRis WhEEL   0Z1nbG2KOuRKntstSAkSox
# 19                                           Señorita  6v3KW9xbzN5yKLt9YKDYA2
# 20                                     Lover (Remix)   3i9UVldZOE0aD0JnyfAZZ0
# 21                                If I Can't Have You  2bT1PH7Cw3J9p3t7nlXCdh
# 22                                   Head Above Water  7gY3cyGcB2wnk2xDXiA0pe
# 23                                      Looking at Me  59tskctgqUmjCWAwhzYAFm
# 24  Don’t Call Me Angel (Charlie’s Angels) (with M...  6zegtH6XXd2PDPLvy1Y0n2
# 25                                    Cheating on You  0ClPIeT6MSgfSgQ9ZrJbAq
# 26                                         Slow Dance  5FNS5Vj69AhRGJWjhrAd01
# 27                             No One Compares To You  4cZ3UsiKd1kUQIaq4BFIj2
# 28                                             Phases  3je88Q4OvTqIx7BFRFYvRA
# 29                                            Perfect  0tgVpDi06FyKpA1z0VMD4v
# 30                               Too Good At Goodbyes  3VlbOrM6nYPprVvzBZllE5
# 31                                              Naked  7krbSH3rd8lhIZvuzTV3Bl
# 32                Perfect Duet (Ed Sheeran & Beyoncé)  1bhUWB0zJMIKr9yVPrkEuI
# 33                              Please Keep Loving Me  78zUxUPvONPgMIt46q5be6
# 34                                      Before You Go  2gMXnyrvIjhVBUZwvLZDMP
# 35                                               Dive  51ChrwmUPDJvedPQnIU8Ls
# 36                                            Burning  7FyhrRNRJOZSM8IeuAx7su
# 37                                              Naked  7krbSH3rd8lhIZvuzTV3Bl
# 38                Perfect Duet (Ed Sheeran & Beyoncé)  1bhUWB0zJMIKr9yVPrkEuI
# 39                              Please Keep Loving Me  78zUxUPvONPgMIt46q5be6
# 40                                            Forever  12OLyHDxt6dqlAybSPFBK3
#
#                                                   url  \
# 0   https://i.scdn.co/image/ab67616d00001e025675e8...
# 1   https://i.scdn.co/image/ab67616d00001e025675e8...
# 2   https://i.scdn.co/image/ab67616d00001e025675e8...
# 3   https://i.scdn.co/image/ab67616d00001e025675e8...
# 4   https://i.scdn.co/image/ab67616d00001e025675e8...
# 5   https://i.scdn.co/image/ab67616d00001e025675e8...
# 6   https://i.scdn.co/image/ab67616d00001e025675e8...
# 7   https://i.scdn.co/image/ab67616d00001e025675e8...
# 8   https://i.scdn.co/image/ab67616d00001e025675e8...
# 9   https://i.scdn.co/image/ab67616d00001e025675e8...
# 10  https://i.scdn.co/image/ab67616d00001e025675e8...
# 11  https://i.scdn.co/image/ab67616d00001e025675e8...
# 12  https://i.scdn.co/image/ab67616d00001e025675e8...
# 13  https://i.scdn.co/image/ab67616d00001e025675e8...
# 14  https://i.scdn.co/image/ab67616d00001e025675e8...
# 15  https://i.scdn.co/image/ab67616d00001e025675e8...
# 16  https://i.scdn.co/image/ab67616d00001e025675e8...
# 17  https://i.scdn.co/image/ab67616d00001e025675e8...
# 18  https://i.scdn.co/image/ab67616d00001e025675e8...
# 19  https://i.scdn.co/image/ab67616d00001e025675e8...
# 20  https://i.scdn.co/image/ab67616d00001e025675e8...
# 21  https://i.scdn.co/image/ab67616d00001e025675e8...
# 22  https://i.scdn.co/image/ab67616d00001e025675e8...
# 23  https://i.scdn.co/image/ab67616d00001e025675e8...
# 24  https://i.scdn.co/image/ab67616d00001e025675e8...
# 25  https://i.scdn.co/image/ab67616d00001e025675e8...
# 26  https://i.scdn.co/image/ab67616d00001e025675e8...
# 27  https://i.scdn.co/image/ab67616d00001e025675e8...
# 28  https://i.scdn.co/image/ab67616d00001e025675e8...
# 29  https://i.scdn.co/image/ab67616d00001e025675e8...
# 30  https://i.scdn.co/image/ab67616d00001e025675e8...
# 31  https://i.scdn.co/image/ab67616d00001e025675e8...
# 32  https://i.scdn.co/image/ab67616d00001e025675e8...
# 33  https://i.scdn.co/image/ab67616d00001e025675e8...
# 34  https://i.scdn.co/image/ab67616d00001e025675e8...
# 35  https://i.scdn.co/image/ab67616d00001e025675e8...
# 36  https://i.scdn.co/image/ab67616d00001e025675e8...
# 37  https://i.scdn.co/image/ab67616d00001e025675e8...
# 38  https://i.scdn.co/image/ab67616d00001e025675e8...
# 39  https://i.scdn.co/image/ab67616d00001e025675e8...
# 40  https://i.scdn.co/image/ab67616d00001e025675e8...
#
#                   date_added
# 0  2021-04-27 08:09:52+00:00
# 1  2021-04-27 08:09:52+00:00
# 2  2021-04-27 08:09:52+00:00
# 3  2021-04-27 08:09:52+00:00
# 4  2021-04-27 08:09:52+00:00
# 5  2021-04-27 08:09:52+00:00
# 6  2021-04-27 08:09:52+00:00
# 7  2021-04-27 08:09:52+00:00
# 8  2021-04-27 08:09:52+00:00
# 9  2021-04-27 08:09:52+00:00
# 10 2021-04-27 08:09:52+00:00
# 11 2021-04-27 08:09:52+00:00
# 12 2021-04-27 08:09:52+00:00
# 13 2021-04-27 08:09:52+00:00
# 14 2021-04-27 08:09:52+00:00
# 15 2021-04-27 08:09:52+00:00
# 16 2021-04-27 08:09:52+00:00
# 17 2021-04-27 08:09:52+00:00
# 18 2021-04-27 08:09:52+00:00
# 19 2021-04-27 08:09:52+00:00
# 20 2021-04-27 08:09:52+00:00
# 21 2021-04-27 08:09:52+00:00
# 22 2021-04-27 08:09:52+00:00
# 23 2021-04-27 08:09:52+00:00
# 24 2021-04-27 08:09:52+00:00
# 25 2021-04-27 08:09:52+00:00
# 26 2021-04-27 08:09:52+00:00
# 27 2021-04-27 08:09:52+00:00
# 28 2021-04-27 08:09:52+00:00
# 29 2021-04-27 08:09:52+00:00
# 30 2021-04-27 08:09:52+00:00
# 31 2021-04-27 08:09:52+00:00
# 32 2021-04-27 08:09:52+00:00
# 33 2021-04-27 08:09:52+00:00
# 34 2021-04-27 08:09:52+00:00
# 35 2021-04-27 08:09:52+00:00
# 36 2021-04-27 08:09:52+00:00
# 37 2021-04-27 08:09:52+00:00
# 38 2021-04-27 08:09:52+00:00
# 39 2021-04-27 08:09:52+00:00
# 40 2021-04-27 08:09:52+00:00

# %%
try:
    for row in playlist_eve1.itertuples():
        for el in row:
            print(el)
except:
    pass

# %%
from skimage import io
import matplotlib.pyplot as plt

def visualize_songs(df):
    """ 
    Visualize cover art of the songs in the inputted dataframe

    Parameters: 
        df (pandas dataframe): Playlist Dataframe
    """
    
    temp = df['url'].values
    plt.figure(figsize=(15,int(0.625 * len(temp))))
    columns = 5
    
    for i, url in enumerate(temp):
        plt.subplot(len(temp) / columns + 1, columns, i + 1)

        image = io.imread(url)
        plt.imshow(image)
        plt.xticks(color = 'w', fontsize = 0.1)
        plt.yticks(color = 'w', fontsize = 0.1)
        plt.xlabel(df['name'].values[i], fontsize = 12)
        plt.tight_layout(h_pad=0.4, w_pad=0)
        plt.subplots_adjust(wspace=None, hspace=None)

    plt.show()

# %%
# playlist_eve

# %% [markdown]
# ## 4. Create Playlist Vector

# %%
def generate_playlist_feature(complete_feature_set, playlist_df, weight_factor):
    """ 
    Summarize a user's playlist into a single vector

    Parameters: 
        complete_feature_set (pandas dataframe): Dataframe which includes all of the features for the spotify songs
        playlist_df (pandas dataframe): playlist dataframe
        weight_factor (float): float value that represents the recency bias. The larger the recency bias, the most priority recent songs get. Value should be close to 1. 
        
    Returns: 
        playlist_feature_set_weighted_final (pandas series): single feature that summarizes the playlist
        complete_feature_set_nonplaylist (pandas dataframe): 
    """
    
    
    complete_feature_set_playlist = complete_feature_set[complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1).mean(axis =0)
    complete_feature_set_playlist = complete_feature_set_playlist.merge(playlist_df[['id','date_added']], on = 'id', how = 'inner')
    complete_feature_set_nonplaylist = complete_feature_set[~complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1)
    
    playlist_feature_set = complete_feature_set_playlist.sort_values('date_added',ascending=False)

    most_recent_date = playlist_feature_set.iloc[0,-1]
    
    for ix, row in playlist_feature_set.iterrows():
        playlist_feature_set.loc[ix,'months_from_recent'] = int((most_recent_date.to_pydatetime() - row.iloc[-1].to_pydatetime()).days / 30)
        
    playlist_feature_set['weight'] = playlist_feature_set['months_from_recent'].apply(lambda x: weight_factor ** (-x))
    
    playlist_feature_set_weighted = playlist_feature_set.copy()
    #print(playlist_feature_set_weighted.iloc[:,:-4].columns)
    playlist_feature_set_weighted.update(playlist_feature_set_weighted.iloc[:,:-4].mul(playlist_feature_set_weighted.weight,0))
    playlist_feature_set_weighted_final = playlist_feature_set_weighted.iloc[:, :-4]
    #playlist_feature_set_weighted_final['id'] = playlist_feature_set['id']
    
    return playlist_feature_set_weighted_final.sum(axis = 0), complete_feature_set_nonplaylist

# %%
complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM = generate_playlist_feature(complete_feature_set, playlist_eve, 1.09)

# %%
# complete_feature_set_playlist_vector_EDM.shape

# %% [markdown]
# ## 5. Generate Recommendations

# %%
def generate_playlist_recos(df, features, nonplaylist_features):
    """ 
    Pull songs from a specific playlist.

    Parameters: 
        df (pandas dataframe): spotify dataframe
        features (pandas series): summarized playlist feature
        nonplaylist_features (pandas dataframe): feature set of songs that are not in the selected playlist
        
    Returns: 
        non_playlist_df_top_40: Top 40 recommendations for that playlist
    """
    client_id = '79ca288b68884e198c53146b51adfa1e'
    client_secret= '63242b064ebb4e379bfca173dd482e79'
    auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(auth_manager=auth_manager)
    
    non_playlist_df = df[df['id'].isin(nonplaylist_features['id'].values)]
    non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('id', axis = 1).values, features.values.reshape(1, -1))[:,0]
    non_playlist_df_top_40 = non_playlist_df.sort_values('sim',ascending = False).head(40)
    non_playlist_df_top_40['url'] = non_playlist_df_top_40['id'].apply(lambda x: sp.track(x)['album']['images'][1]['url'])
    
    return non_playlist_df_top_40

# %%
edm_top40 = generate_playlist_recos(spotify_df, complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM)

# %%
edm_top40.columns
# Out:
# Index(['index', 'valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo', 'artists_upd_v1', 'artists_upd_v2',
#        'artists_upd', 'artists_song', 'popularity_red', 'sim', 'url'],
#       dtype='object')

# %%
dict = {'A':[1,2,3,4],'B':[16,2,36,46],'C':[14,24,4636,4],'D':[41,2,34,644]}
df = pd.DataFrame(dict,index=[1,2,3,4])

# %%
l = [1,2,3,4]
ind_list = []
for row in df.itertuples():
    if row[1] in l:
        df.drop(row[0],inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
tmp = edm_top40
l = []
s = set()

for i in range(40):
    if tmp.iloc[i]['artists'] in s:
        l.append(tmp.iloc[i].name)
    else:
        s.add(tmp.iloc[i]['artists'])

tmp.drop(l, inplace=True)

# %%
tmp
# Out:
#         index  valence  year  acousticness  \
# 34066  154379    0.466  2011       0.00382
# 8047    38494    0.326  2015       0.91900
# 8037    38484    0.152  2017       0.34300
# 20544   90165    0.249  2014       0.16200
# 26072  120458    0.239  2019       0.75800
# 28308  130276    0.329  2011       0.81000
# 33516  152009    0.488  2014       0.03310
# 26649  122602    0.554  2015       0.53000
# 21133   92426    0.161  2011       0.22900
# 25551  117845    0.212  2011       0.58000
#
#                                           artists  danceability  duration_ms  \
# 34066                                   ['Adele']         0.610       241693
# 8047                 ['Sam Smith', 'John Legend']         0.468       219536
# 8037                       ['Sam Smith', 'Yebba']         0.660       283295
# 20544                             ['Jessie Ware']         0.387       257484
# 26072                     ['Ed Sheeran', 'Yebba']         0.565       243267
# 28308                      ['Corinne Bailey Rae']         0.683       208636
# 33516                              ['Aloe Blacc']         0.308       254880
# 26649  ['Donnie Trumpet & The Social Experiment']         0.511       226014
# 21133                          ['James Morrison']         0.537       229303
# 25551                              ['Emily King']         0.747       243533
#
#        energy  explicit                      id  ...  release_date  \
# 34066   0.683         0  3CKCZ9pfwAfoMZlMncA1Nc  ...    2011-01-19
# 8047    0.190         0  64GRDrL1efgXclrhVCeuA0  ...    2015-11-06
# 8037    0.542         0  75TlwJ8oBgdq8P9kO7uVML  ...    2017-11-03
# 20544   0.413         0  71AATBHZGo82EnjZnG53Zx  ...    2014-08-04
# 26072   0.243         0  0VsGaRXR5WAzpu51unJTis  ...    2019-07-12
# 28308   0.333         0  5FvapYqWK6TEuh4csYwQ9O  ...    2011-01-01
# 33516   0.769         0  2stPxcgjdSImK7Gizl8ZUN  ...    2014-01-01
# 26649   0.596         0  6fTdcGsjxlAD9PSkoPaLMX  ...    2015-06-30
# 21133   0.611         0  2TUzU4IkfH8kcvY2MUlsd2  ...    2011-01-01
# 25551   0.224         0  4Aj1eHsMtEmjpJUWdUWiVa  ...    2011-07-12
#
#        speechiness    tempo                            artists_upd_v1  \
# 34066       0.0253  108.003                                   [Adele]
# 8047        0.0373  125.319                  [Sam Smith, John Legend]
# 8037        0.0770  135.828                        [Sam Smith, Yebba]
# 20544       0.0559  173.730                             [Jessie Ware]
# 26072       0.0317   81.655                       [Ed Sheeran, Yebba]
# 28308       0.0434  123.804                      [Corinne Bailey Rae]
# 33516       0.0650   81.853                              [Aloe Blacc]
# 26649       0.2240  158.063  [Donnie Trumpet & The Social Experiment]
# 21133       0.0304  105.955                          [James Morrison]
# 25551       0.0649  105.014                              [Emily King]
#
#        artists_upd_v2                               artists_upd  \
# 34066              []                                   [Adele]
# 8047               []                  [Sam Smith, John Legend]
# 8037               []                        [Sam Smith, Yebba]
# 20544              []                             [Jessie Ware]
# 26072              []                       [Ed Sheeran, Yebba]
# 28308              []                      [Corinne Bailey Rae]
# 33516              []                              [Aloe Blacc]
# 26649              []  [Donnie Trumpet & The Social Experiment]
# 21133              []                          [James Morrison]
# 25551              []                              [Emily King]
#
#                                             artists_song popularity_red  \
# 34066                          AdeleSet Fire to the Rain             15
# 8047                                Sam SmithLay Me Down             15
# 8037                                   Sam SmithNo Peace             11
# 20544                         Jessie WareSay You Love Me             11
# 26072            Ed SheeranBest Part of Me (feat. YEBBA)             13
# 28308                     Corinne Bailey RaeIs This Love             11
# 33516                                  Aloe BlaccThe Man             12
# 26649  Donnie Trumpet & The Social ExperimentSunday C...             13
# 21133                   James MorrisonI Won't Let You Go             12
# 25551                                  Emily KingGeorgia             10
#
#             sim                                                url
# 34066  0.999782  https://i.scdn.co/image/ab67616d00001e026d4056...
# 8047   0.871500  https://i.scdn.co/image/ab67616d00001e02de48dc...
# 8037   0.856851  https://i.scdn.co/image/ab67616d00001e02f3ea71...
# 20544  0.854143  https://i.scdn.co/image/ab67616d00001e021c021b...
# 26072  0.853983  https://i.scdn.co/image/ab67616d00001e0273304c...
# 28308  0.837490  https://i.scdn.co/image/ab67616d00001e02e99107...
# 33516  0.836387  https://i.scdn.co/image/ab67616d00001e02363fc5...
# 26649  0.835235  https://i.scdn.co/image/ab67616d00001e0242bf3f...
# 21133  0.826811  https://i.scdn.co/image/ab67616d00001e029accc4...
# 25551  0.826299  https://i.scdn.co/image/ab67616d00001e02f381df...
#
# [10 rows x 27 columns]
